# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# - Ways to create dataset
#   - dictionary of items
#   - list of items
#   - import csv files
#   - importing excel files
#   - importing json files
# - reading data
# - selection of data
# - manipulating the data
# - visualizing the data

# %%
books = {'Title' : ['The Hobbit', 'The Catcher in the Rye', '1984', 'The Little Prince', 'The Da Vinci Code'],
         'Author' : ['J.R.R. Tolkien', 'J D Salingar', 'George Orwell', 'Antoine de Saint Expery', 'Dan Brown'],
         'Published': [1937, 1951, 1949, 1943, 2003],
         'price': [399, 199, 299, 199, 499]
} 
pd.DataFrame(books)
# Out:
#                     Title                   Author  Published  price
# 0              The Hobbit           J.R.R. Tolkien       1937    399
# 1  The Catcher in the Rye             J D Salingar       1951    199
# 2                    1984            George Orwell       1949    299
# 3       The Little Prince  Antoine de Saint Expery       1943    199
# 4       The Da Vinci Code                Dan Brown       2003    499

# %%
movies = [
    {'Title': 'The Hobbit', 'Director': 'peter Jackson', 'Released': 2012, 'Length': 169},
    {'Title': 'The Catcher in the Rye', 'Director': 'Danny Strong', 'Released': 2017, 'Length': 106},
    {'Title': '1984', 'Director': 'Michael Radford', 'Released': 1984, 'Length': 113}
]
pd.DataFrame(movies)
# Out:
#                     Title         Director  Released  Length
# 0              The Hobbit    peter Jackson      2012     169
# 1  The Catcher in the Rye     Danny Strong      2017     106
# 2                    1984  Michael Radford      1984     113

# %%
url = "https://raw.githubusercontent.com/digipodium/Datasets/main/regression/kc_house_data.csv"
df = pd.read_csv(url)
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.tail()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608        1530              0      2009             0    98103  47.6993
# ...

# %%
df.sample(5)
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 346    3969300030  20141229T000000  239900.0         4       1.00
# 6103   9485940290  20150512T000000  464950.0         4       2.25
# 12090  1428001160  20150420T000000  550000.0         3       1.75
# 16489  1545807280  20140628T000000  314500.0         3       1.75
# 19248  1645000580  20141002T000000  270000.0         4       2.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 346           1000      7134     1.0           0     0  ...      6
# 6103          2350     36116     1.0           0     0  ...      9
# 12090         1890    100623     1.0           0     3  ...      8
# 16489         1700     17355     1.0           0     0  ...      7
# 19248         1900      8282     1.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 346          1000              0      1943             0    98178  47.4897
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.describe(include='object')
# Out:
#                    date
# count             21613
# unique              372
# top     20140623T000000
# freq                142

# %%
df.describe(include='int64')
# Out:
#                  id      bedrooms   sqft_living      sqft_lot    waterfront  \
# count  2.161300e+04  21613.000000  21613.000000  2.161300e+04  21613.000000
# mean   4.580302e+09      3.370842   2079.899736  1.510697e+04      0.007542
# std    2.876566e+09      0.930062    918.440897  4.142051e+04      0.086517
# min    1.000102e+06      0.000000    290.000000  5.200000e+02      0.000000
# 25%    2.123049e+09      3.000000   1427.000000  5.040000e+03      0.000000
# 50%    3.904930e+09      3.000000   1910.000000  7.618000e+03      0.000000
# 75%    7.308900e+09      4.000000   2550.000000  1.068800e+04      0.000000
# max    9.900000e+09     33.000000  13540.000000  1.651359e+06      1.000000
#
#                view     condition         grade    sqft_above  sqft_basement  \
# count  21613.000000  21613.000000  21613.000000  21613.000000   21613.000000
# mean       0.234303      3.409430      7.656873   1788.390691     291.509045
# ...

# %%
df.shape
# Out:
# (21613, 21)

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['id',
#  'date',
#  'price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %% [markdown]
# ## Selecting data in pandas
#  - rows
#     - iloc : index based location
#     - loc : label based location
#
#  - columns
#     - single column selection
#     - multiple column selection
#     - column selection by datatype

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.iloc[1]
# Out:
# id                    6414100192
# date             20141209T000000
# price                   538000.0
# bedrooms                       3
# bathrooms                   2.25
# sqft_living                 2570
# sqft_lot                    7242
# floors                       2.0
# waterfront                     0
# view                           0
# condition                      3
# grade                          7
# sqft_above                  2170
# sqft_basement                400
# yr_built                    1951
# yr_renovated                1991
# zipcode                    98125
# lat                       47.721
# long                    -122.319
# sqft_living15               1690
# sqft_lot15                  7639
# Name: 1, dtype: object

# %%
df.iloc[100]
# Out:
# id                    1952200240
# date             20140611T000000
# price                   850830.0
# bedrooms                       3
# bathrooms                    2.5
# sqft_living                 2070
# sqft_lot                   13241
# floors                       1.5
# waterfront                     0
# view                           0
# condition                      5
# grade                          9
# sqft_above                  1270
# sqft_basement                800
# yr_built                    1910
# yr_renovated                   0
# zipcode                    98102
# lat                      47.6415
# long                    -122.315
# sqft_living15               2200
# sqft_lot15                  4500
# Name: 100, dtype: object

# %%
#Selecting random 5 rows 
df.iloc[[1, 59, 100, 200, 300]]
# Out:
#              id             date      price  bedrooms  bathrooms  sqft_living  \
# 1    6414100192  20141209T000000   538000.0         3       2.25         2570
# 59   8079040320  20150223T000000   430000.0         4       3.00         1850
# 100  1952200240  20140611T000000   850830.0         3       2.50         2070
# 200  3542300060  20150311T000000   210000.0         3       1.00          860
# 300  3225069065  20140624T000000  3075000.0         4       5.00         4550
#
#      sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 1        7242     2.0           0     0  ...      7        2170
# 59       9976     2.0           0     0  ...      8        1850
# 100     13241     1.5           0     0  ...      9        1270
# 200     11725     1.0           0     0  ...      6         860
# 300     18641     1.0           1     4  ...     10        2600
#
#      sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
#Selecting random 3 rows with selected columns
df.iloc[[1,10,20], [0, 1, 5]]
# Out:
#             id             date  sqft_living
# 1   6414100192  20141209T000000         2570
# 10  1736800520  20150403T000000         3560
# 20  6300500875  20140514T000000         1620

# %%
df.iloc[20:58, :10]
# Out:
#             id             date      price  bedrooms  bathrooms  sqft_living  \
# 20  6300500875  20140514T000000   385000.0         4       1.75         1620
# 21  2524049179  20140826T000000  2000000.0         3       2.75         3050
# 22  7137970340  20140703T000000   285000.0         5       2.50         2270
# 23  8091400200  20140516T000000   252700.0         2       1.50         1070
# 24  3814700200  20141120T000000   329000.0         3       2.25         2450
# 25  1202000200  20141103T000000   233000.0         3       2.00         1710
# 26  1794500383  20140626T000000   937000.0         3       1.75         2450
# 27  3303700376  20141201T000000   667000.0         3       1.00         1400
# 28  5101402488  20140624T000000   438000.0         3       1.75         1520
# 29  1873100390  20150302T000000   719000.0         4       2.50         2570
# 30  8562750320  20141110T000000   580500.0         3       2.50         2320
# ...

# %%
df = df.set_index('id')
df.head()
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900.0         3       1.00         1180
# 6414100192  20141209T000000  538000.0         3       2.25         2570
# 5631500400  20150225T000000  180000.0         2       1.00          770
# 2487200875  20141209T000000  604000.0         4       3.00         1960
# 1954400510  20150218T000000  510000.0         3       2.00         1680
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# 7129300520      5650     1.0           0     0          3      7        1180
# 6414100192      7242     2.0           0     0          3      7        2170
# 5631500400     10000     1.0           0     0          3      6         770
# 2487200875      5000     1.0           0     0          5      7        1050
# 1954400510      8080     1.0           0     0          3      8        1680
#
# ...

# %%
df.loc[[7129300520, 2487200875]]
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900.0         3        1.0         1180
# 2487200875  20141209T000000  604000.0         4        3.0         1960
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# 7129300520      5650     1.0           0     0          3      7        1180
# 2487200875      5000     1.0           0     0          5      7        1050
#
#             sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# id
# 7129300520              0      1955             0    98178  47.5112 -122.257
# 2487200875            910      1965             0    98136  47.5208 -122.393
#
#             sqft_living15  sqft_lot15
# id
# 7129300520           1340        5650
# 2487200875           1360        5000

# %% [markdown]
# Single column selection
#
#  - dictionary like selection
#    - dataframe['column_name']
#  - object like selection
#    - dataframe['column_name']
#
# Multiple column selection
#
# - dictionary like selection
#   - dataframe[list_of_column_name]

# %%
df['price']
# Out:
# id
# 7129300520    221900.0
# 6414100192    538000.0
# 5631500400    180000.0
# 2487200875    604000.0
# 1954400510    510000.0
#                 ...
# 263000018     360000.0
# 6600060120    400000.0
# 1523300141    402101.0
# 291310100     400000.0
# 1523300157    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
df.bedrooms
# Out:
# id
# 7129300520    3
# 6414100192    3
# 5631500400    2
# 2487200875    4
# 1954400510    3
#              ..
# 263000018     3
# 6600060120    4
# 1523300141    2
# 291310100     3
# 1523300157    2
# Name: bedrooms, Length: 21613, dtype: int64

# %%
df[['price', 'bedrooms', 'bathrooms']]
# Out:
#                price  bedrooms  bathrooms
# id
# 7129300520  221900.0         3       1.00
# 6414100192  538000.0         3       2.25
# 5631500400  180000.0         2       1.00
# 2487200875  604000.0         4       3.00
# 1954400510  510000.0         3       2.00
# ...              ...       ...        ...
# 263000018   360000.0         3       2.50
# 6600060120  400000.0         4       2.50
# 1523300141  402101.0         2       0.75
# 291310100   400000.0         3       2.50
# 1523300157  325000.0         2       0.75
#
# [21613 rows x 3 columns]

# %% [markdown]
# Manipulating and Cleaning Data
#
#  - removing rows and  column
#  - rename column names
#  - addi ng columns
#  - changing dataype
#  - handling missing values
#  - dropping missing values
#  - using apply() method

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
cols_to_drop = ['sqft_living15', 'sqft_lot15']
df = df.drop(cols_to_drop, axis=1)
df.head()
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900.0         3       1.00         1180
# 6414100192  20141209T000000  538000.0         3       2.25         2570
# 5631500400  20150225T000000  180000.0         2       1.00          770
# 2487200875  20141209T000000  604000.0         4       3.00         1960
# 1954400510  20150218T000000  510000.0         3       2.00         1680
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# 7129300520      5650     1.0           0     0          3      7        1180
# 6414100192      7242     2.0           0     0          3      7        2170
# 5631500400     10000     1.0           0     0          3      6         770
# 2487200875      5000     1.0           0     0          5      7        1050
# 1954400510      8080     1.0           0     0          3      8        1680
#
# ...

# %%
df.drop(labels = [7129300520,1954400510])
# Out:
#                        date      price  bedrooms  bathrooms  sqft_living  \
# id
# 6414100192  20141209T000000   538000.0         3       2.25         2570
# 5631500400  20150225T000000   180000.0         2       1.00          770
# 2487200875  20141209T000000   604000.0         4       3.00         1960
# 7237550310  20140512T000000  1225000.0         4       4.50         5420
# 1321400060  20140627T000000   257500.0         3       2.25         1715
# ...                     ...        ...       ...        ...          ...
# 263000018   20140521T000000   360000.0         3       2.50         1530
# 6600060120  20150223T000000   400000.0         4       2.50         2310
# 1523300141  20140623T000000   402101.0         2       0.75         1020
# 291310100   20150116T000000   400000.0         3       2.50         1600
# 1523300157  20141015T000000   325000.0         2       0.75         1020
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# ...

# %%
df.dropna()
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900.0         3       1.00         1180
# 6414100192  20141209T000000  538000.0         3       2.25         2570
# 5631500400  20150225T000000  180000.0         2       1.00          770
# 2487200875  20141209T000000  604000.0         4       3.00         1960
# 1954400510  20150218T000000  510000.0         3       2.00         1680
# ...                     ...       ...       ...        ...          ...
# 263000018   20140521T000000  360000.0         3       2.50         1530
# 6600060120  20150223T000000  400000.0         4       2.50         2310
# 1523300141  20140623T000000  402101.0         2       0.75         1020
# 291310100   20150116T000000  400000.0         3       2.50         1600
# 1523300157  20141015T000000  325000.0         2       0.75         1020
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# ...

# %%
#to rename the columns name 
name_update = {
    'lat' : 'latitude',
    'long' : 'longitude'
}
df.rename(columns = name_update)
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900.0         3       1.00         1180
# 6414100192  20141209T000000  538000.0         3       2.25         2570
# 5631500400  20150225T000000  180000.0         2       1.00          770
# 2487200875  20141209T000000  604000.0         4       3.00         1960
# 1954400510  20150218T000000  510000.0         3       2.00         1680
# ...                     ...       ...       ...        ...          ...
# 263000018   20140521T000000  360000.0         3       2.50         1530
# 6600060120  20150223T000000  400000.0         4       2.50         2310
# 1523300141  20140623T000000  402101.0         2       0.75         1020
# 291310100   20150116T000000  400000.0         3       2.50         1600
# 1523300157  20141015T000000  325000.0         2       0.75         1020
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# ...

# %%
df.yr_built.dtype
# Out:
# dtype('int64')

# %%
df.yr_built.astype('float')
# Out:
# id
# 7129300520    1955.0
# 6414100192    1951.0
# 5631500400    1933.0
# 2487200875    1965.0
# 1954400510    1987.0
#                ...
# 263000018     2009.0
# 6600060120    2014.0
# 1523300141    2009.0
# 291310100     2004.0
# 1523300157    2008.0
# Name: yr_built, Length: 21613, dtype: float64

# %%
df.yr_built.unique()
# Out:
# array([1955, 1951, 1933, 1965, 1987, 2001, 1995, 1963, 1960, 2003, 1942,
#        1927, 1977, 1900, 1979, 1994, 1916, 1921, 1969, 1947, 1968, 1985,
#        1941, 1915, 1909, 1948, 2005, 1929, 1981, 1930, 1904, 1996, 2000,
#        1984, 2014, 1922, 1959, 1966, 1953, 1950, 2008, 1991, 1954, 1973,
#        1925, 1989, 1972, 1986, 1956, 2002, 1992, 1964, 1952, 1961, 2006,
#        1988, 1962, 1939, 1946, 1967, 1975, 1980, 1910, 1983, 1978, 1905,
#        1971, 2010, 1945, 1924, 1990, 1914, 1926, 2004, 1923, 2007, 1976,
#        1949, 1999, 1901, 1993, 1920, 1997, 1943, 1957, 1940, 1918, 1928,
#        1974, 1911, 1936, 1937, 1982, 1908, 1931, 1998, 1913, 2013, 1907,
#        1958, 2012, 1912, 2011, 1917, 1932, 1944, 1902, 2009, 1903, 1970,
#        2015, 1934, 1938, 1919, 1906, 1935])
